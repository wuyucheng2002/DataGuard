# %%
import pandas as pd

# %%
pd.read_excel('./医保_个人基本信息.xlsx')
# Out:
#     aaa027 aae004 aac003     aac010       aac067    bac557   bab306  \
# 0      统筹区    联系人     姓名  户口所在地详细地址         手机号码  居住证所在地地址  常住地详细地址
# 1   320402    NaN    李**        NaN  137****9508       NaN   ******
# 2   320482    NaN    朱**        NaN  138****4944       NaN       付业
# 3   320401    NaN    恽**        NaN  180****9943       NaN   ******
# 4   320404    NaN    孙**        NaN  180****0766       NaN   ******
# 5   320401    NaN    王**        NaN  139****0139       NaN   ******
# 6   320412    NaN    吴**        NaN          NaN       NaN   ******
# 7   320402    NaN    张**        NaN  189****3052       NaN   ******
# 8   320412    NaN    吴**        NaN          NaN       NaN   ******
# 9   320401    NaN    庄**        NaN          NaN       NaN   ******
# 10  320404    NaN    邓**        NaN  176****9196       NaN   ******
# 11  320402    NaN    张**        NaN  183****1462       NaN   ******
# 12  320401    NaN    殷**        NaN          NaN       NaN   ******
# ...

# %%
data = _

# %%
data.dropna(axis=1, how='any', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   aaa027  54 non-null     object
#  1   aac003  54 non-null     object
#  2   bab306  54 non-null     object
#  3   sfz_bm  54 non-null     object
#  4   aac001  54 non-null     object
#  5   aac004  54 non-null     object
#  6   aac005  54 non-null     object
#  7   aac006  54 non-null     object
#  8   aac009  54 non-null     object
#  9   aac058  54 non-null     object
#  10  aac084  54 non-null     object
#  11  aac161  54 non-null     object
#  12  aac999  54 non-null     object
#  13  aae100  54 non-null     object
#  14  akc021  54 non-null     object
#  15  bac062  54 non-null     object
# dtypes: object(16)
# memory usage: 6.9+ KB

# %%
data
# Out:
#     aaa027 aac003   bab306                            sfz_bm  \
# 0      统筹区     姓名  常住地详细地址                             身份证编码
# 1   320402    李**   ******  12064d0e1c1442b64cdcb21dbc48f36a
# 2   320482    朱**       付业  2568f814caa1560e111d714905e470f5
# 3   320401    恽**   ******  499bcdcfdd4422cac02b9f9e53038a80
# 4   320404    孙**   ******  6a97a6e1abbfda7038c3e59a1fa0e2d6
# 5   320401    王**   ******  fcab2e53f88b5094598f6e1b0942e394
# 6   320412    吴**   ******  9f22c62ad6cfe6f34c8bb13e6361bac4
# 7   320402    张**   ******  9ee0d890342e38a375f896e5a36fe6e7
# 8   320412    吴**   ******  9f22c62ad6cfe6f34c8bb13e6361bac4
# 9   320401    庄**   ******  a76bd04f43915afcea7800e6ddb98d6c
# 10  320404    邓**   ******  2b73bec077333ef521bb20ee58e0f264
# 11  320402    张**   ******  bcd1a66fe98b4529192c0ca7a8728bd8
# 12  320401    殷**   ******  19943351ffeebf233fda2308086a3c48
# 13  320412    王**   ******  2ec07d0b0526999d511c1ab235e6ad7d
# ...

# %% [markdown]
# 隐私属性：户口性质-8 aac009 aac084
# 任务属性：离退休状态-10 aac084

# %%
data.iloc[0,:]
# Out:
# aaa027        统筹区
# aac003         姓名
# bab306    常住地详细地址
# sfz_bm      身份证编码
# aac001       个人编号
# aac004         性别
# aac005         民族
# aac006       出生日期
# aac009       户口性质
# aac058       证件类型
# aac084      离退休状态
# aac161    国家/地区代码
# aac999      一体化编号
# aae100       有效标志
# akc021     医疗待遇类别
# bac062     人员登记状态
# Name: 0, dtype: object

# %%
data_ = data.iloc[1:, :]

# %%
data_
# Out:
#     aaa027 aac003  bab306                            sfz_bm            aac001  \
# 1   320402    李**  ******  12064d0e1c1442b64cdcb21dbc48f36a  1009345096666883
# 2   320482    朱**      付业  2568f814caa1560e111d714905e470f5  1200006795566544
# 3   320401    恽**  ******  499bcdcfdd4422cac02b9f9e53038a80  1009345097029096
# 4   320404    孙**  ******  6a97a6e1abbfda7038c3e59a1fa0e2d6  1009345097437016
# 5   320401    王**  ******  fcab2e53f88b5094598f6e1b0942e394  1009345096919053
# 6   320412    吴**  ******  9f22c62ad6cfe6f34c8bb13e6361bac4  1400000002434370
# 7   320402    张**  ******  9ee0d890342e38a375f896e5a36fe6e7  1009345095598984
# 8   320412    吴**  ******  9f22c62ad6cfe6f34c8bb13e6361bac4  1400000001687619
# 9   320401    庄**  ******  a76bd04f43915afcea7800e6ddb98d6c  1009345094856177
# 10  320404    邓**  ******  2b73bec077333ef521bb20ee58e0f264  1009345097582623
# 11  320402    张**  ******  bcd1a66fe98b4529192c0ca7a8728bd8  2000006497382849
# ...

# %%
cat_index = [i for i in range(len(data_.columns))]
cat_index.remove(7)
num_index = [7]

# %%
for i in cat_index:
    data_.iloc[:, i] = data_.iloc[:, i].astype('str')
# Out:
# C:\Users\13015\AppData\Local\Temp\ipykernel_11072\1125614521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_.iloc[:, i] = data_.iloc[:, i].astype('str')
# C:\Users\13015\AppData\Local\Temp\ipykernel_11072\1125614521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_.iloc[:, i] = data_.iloc[:, i].astype('str')
# C:\Users\13015\AppData\Local\Temp\ipykernel_11072\1125614521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
for i in num_index:
    data_.iloc[:, i] = data_.iloc[:, i].astype('int')
# Out:
# C:\Users\13015\AppData\Local\Temp\ipykernel_11072\2113561549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_.iloc[:, i] = data_.iloc[:, i].astype('int')

# %%
data_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 1 to 53
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   aaa027  53 non-null     object
#  1   aac003  53 non-null     object
#  2   bab306  53 non-null     object
#  3   sfz_bm  53 non-null     object
#  4   aac001  53 non-null     object
#  5   aac004  53 non-null     object
#  6   aac005  53 non-null     object
#  7   aac006  53 non-null     int32
#  8   aac009  53 non-null     object
#  9   aac058  53 non-null     object
#  10  aac084  53 non-null     object
#  11  aac161  53 non-null     object
#  12  aac999  53 non-null     object
#  13  aae100  53 non-null     object
#  14  akc021  53 non-null     object
#  15  bac062  53 non-null     object
# dtypes: int32(1), object(15)
# memory usage: 6.5+ KB

# %%
data_.drop(axis=1, columns=['aac009', 'aac084'], inplace=True)
# Out:
# C:\Users\13015\AppData\Local\Temp\ipykernel_11072\2015740661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_.drop(axis=1, columns=['aac009', 'aac084'], inplace=True)

# %%
data_.columns
# Out:
# Index(['aaa027', 'aac003', 'bab306', 'sfz_bm', 'aac001', 'aac004', 'aac005',
#        'aac006', 'aac058', 'aac161', 'aac999', 'aae100', 'akc021', 'bac062'],
#       dtype='object')

# %%
cat_col = ['aaa027', 'aac003', 'bab306', 'sfz_bm', 'aac001', 'aac004', 'aac005', 'aac058', 'aac161', 'aac999', 'aae100', 'akc021', 'bac062']
num_col = ['aac006']

# %%
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler
from sklearn.compose import ColumnTransformer

# %%
scaler = MinMaxScaler()
encoder = OneHotEncoder()

# %%
pipeline = ColumnTransformer(
    ['num', ']
)
